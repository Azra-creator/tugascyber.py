# %% [markdown]
# <a href="https://colab.research.google.com/github/Azra-creator/tugascyber.py/blob/main/UAS_Kapsel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tittle:
#
# **Goals:**
# <a name="id"></a>
#
# [**1 of 7 · Abstraksi / Abstract (no citation)**](#1)
#
# [**2 of 7 · Pendahuluan / Introduction**](#2)
#
# [**3 of 7 · Metodologi / Methodology**](#3)
#
# [**4 of 7 · Proses Pembuatan / Process Detailing**](#4)
#
# [**5 of 7 · Hasil, Diskusi, dan Evaluasi / Results, Discussion, and Evaluation**](#5)
#
# [**6 of 7 · Kesimpulan dan Saran / Conclusion and Recommendation (no citation)**](#6)
#
# [**7 of 7 · Daftar Pustaka / References**](#7)

# %% [markdown]
# <a name="1"></a>
#
# **1 of 7 · Abstraksi / Abstract**

# %% [markdown]
# It contains a summary of the process carried out from beginning to end

# %% [markdown]
# <a name="id"></a>
# [**Back to HOME**](#100)

# %% [markdown]
# <a name="2"></a>
#
# **2 of 7 · Pendahuluan / Introduction**

# %% [markdown]
# * 1-4 pages total:

# %% [markdown]
# There are 4 important paragraphs in the introduction, namely:
#
# * Overall, about topic of interest (min 3 citation)
# * Explanation of the problem statement (general problem and specific) (min 3 citation)
# * Existing solution and limitations (min 3 citation)
# * Description of your approach to solve the problem (min 3 citation)

# %% [markdown]
# <a name="id"></a>
# [**Back to HOME**](#100)

# %% [markdown]
# <a name="3"></a>
#
# **3 of 7 · Metodologi / Methodology**

# %% [markdown]
# * There must be a flowchart that explains the process from start to finish (JPG, PNG).
# * A list of important points and their brief explanations will be created.
# * Example:
#
#     - 1. Dataset: dataset is...
#     - 2. Library: library is...
#     - 3. Data Cleaning: data cleaning is...

# %% [markdown]
# <a name="id"></a>
# [**Back to HOME**](#100)

# %% [markdown]
# <a name="4"></a>
#
# **4 of 7 · Proses Pembuatan / Process/ Detailing from Methodology**

# %% [markdown]
# In this stage, we provide detailed information based on the points of methodology.
#
# 1. Dataset...
# 2. Library...
# 3. Data Cleaning...

# %% [markdown]
# <a name="id"></a>
# [**Back to HOME**](#100)

# %% [markdown]
# <a name="5"></a>
#
# **5 of 7 · Hasil, Diskusi, dan Evaluasi / Results, Discussion, and Evaluation**

# %% [markdown]
# <a name="id"></a>
# [**Back to HOME**](#100)

# %% [markdown]
# <a name="6"></a>
#
# **6 of 7 · Concluton dan Recommendation / Evaluation and Recommendation**

# %% [markdown]
# <a name="id"></a>
# [**Back to HOME**](#100)

# %% [markdown]
# <a name="7"></a>
#
# **7 of 7 · Daftar Pustaka / References**
#
# Using IEEEE format:

# %% [markdown]
# [1] Rejda, G. E., & McNamara, M. (2018). Principles of Risk Management and Insurance. Pearson.
#
# [2] Jerry II, R. H., & Richmond, D. R. (2012). Understanding Insurance Law. LexisNexis.
#
# [3] Wajidi, F. (2018). Asuransi dan Hukumnya. Sinar Grafika.
#
# [4] Aziz, A., & Hafidz, A. (2019). Tanggung Jawab Perusahaan Asuransi dalam Memberikan Ganti Rugi Bagi Nasabah. Jurnal Hukum & Pembangunan, 49(3), 454-468.
#
# [5] Azwar, M., & Hashim, M. H. (2018). Analisis Perlindungan Hukum Terhadap Pemegang Polis Asuransi. Jurnal Kajian Ilmu Hukum, 6(3), 231-244.
#
# [6] Amiruddin. (2021). Teori dan Praktek Asuransi. Prenadamedia Group.
#
# [7] Rosyadi, I., & Ma'ruf, F. (2019). The Effect of Service Quality on Customer Satisfaction and Its Implications for Customer Loyalty in Insurance Companies. Journal of Business and Finance Management Research, 3(1), 1-10.
#
# [8] Cummins, J. D., Weiss, M. A., & Zi, H. (2019). The Economics of Insurance and Its Borders with Finance and Actuarial Science: A Survey. Journal of Financial Services Research, 55(1), 1-27.
#
# [9] Jafari, H., Amini, M., & Rostamy, A. A. A. (2021). Demand for Life Insurance: An International Comparison. Journal of Risk and Insurance, 88(1), 77-112.
#
# [10] Marrison, C. (2012). The Fundamentals of Risk Measurement. McGraw-Hill Education.
#
# [11] Cousineau, M. R., & Tahir, F. (2020). Health Insurance. Springer.
#
# [12] Hsu, M., Shiu, Y. M., & Huang, S. Y. (2017). Forecasting Health Insurance Costs: A Comparison of Time Series Methods. Journal of Insurance Issues, 40(1), 69-98.
#
# [13] Burke, J. (2013). Health Analytics: Gaining the Insights to Transform Health Care. John Wiley & Sons.
#
# [14] Zhang, J., Wu, B., Li, M., & Zhu, G. (2021). Health Insurance Premium Prediction Based on Machine Learning: A Comparative Study of Regression Models. Journal of Healthcare Engineering, 2021, 1-9.
#
# [15] Bellini, T., Liu, M., & Ch'Ng, K. S. (2020). Forecasting and Simulating Health Care Expenditures: A Machine Learning Approach. Journal of Risk and Insurance, 87(2), 511-542.
#
# [16] Pauly, M., Mitchell, O. S., Zeng, Y., & Buchmueller, T. (2018). Will the Individual Health Insurance Market Survive? Health Affairs, 58, 67-81.
#
# [17] Harrington, S., & Niehaus, G. (2019). Risk Management and Insurance (3rd ed.). McGraw-Hill.
#
# [18] McKinney, W. (2017). Python for Data Analysis. O'Reilly Media.
#
# [19] Johansson, R. (2020). Numerical Python: Scientific Computing and Data Science Applications with Numpy. Apress.
#
# [20] Waskom, M. (2020). Seaborn: Statistical data visualization. Journal of Open Source Software, 5(47), 1995.
#
# [21] Hunter, J. D. (2007). Matplotlib: A 2D graphics environment. Computing in Science & Engineering, 9(3), 90-95.
#
# [22] Raschka, S., & Mirjalili, V. (2019). Python Machine Learning. Packt Publishing.
#
# [23] Pedregosa, F., Varoquaux, G., Gramfort, A., Michel, V., Thirion, B., Grisel, O., ... & Vanderplas, J. (2011). Scikit-learn: Machine learning in Python. Journal of Machine Learning Research, 12, 2825-2830.
#
# [24] Müller, A. C., & Guido, S. (2016). Introduction to Machine Learning with Python. O'Reilly Media.
#
# [25] Géron, A. (2019). Hands-On Machine Learning with Scikit-Learn, Keras, and TensorFlow. O'Reilly Media.
#
# [26] James, G., Witten, D., Hastie, T., & Tibshirani, R. (2017). An Introduction to Statistical Learning: With Applications in R. Springer.
#
# [27] Breiman, L., Friedman, J., Stone, C. J., & Olshen, R. A. (2001). Classification and Regression Trees. Journal of Machine Learning Research, 7(1), 2651-2667.
#
# [28] Bottou, L., Bengio, Y., & LeCun, Y. (2010). Large-scale machine learning with stochastic gradient descent. Journal of Machine Learning Research, 12, 2493-2537.
#
# [29] Kuhn, M., & Johnson, K. (2013). Applied Predictive Modeling. Springer.
#
# [30] Seber, G. A. F., & Lee, A. J. (2013). Linear Regression Analysis. Wiley.
#
# [31] Kutner, M. H., Nachtsheim, C. J., Neter, J., & Li, W. (2013). Applied Linear Regression Models. McGraw-Hill Education.
#
# [32] Montgomery, D. C., Peck, E. A., & Vining, G. G. (2013). Introduction to Linear Regression Analysis. Wiley.
#
# [33] Mehmetoglu, M., & Jakobsen, T. G. (2011). Applied Statistics Using Stata: A Guide for the Social Sciences. Journal of Statistical Software, 45(4), 1-18.
#
# [34] Perktold, J., Seabold, S., & Taylor, J. (2010). Residual Diagnostics and Specification Tests in Regression. Journal of Statistical Software, 27(2), 1-11.
#
# [35] Chatterjee, S., & Hadi, A. S. (2019). Regression Analysis by Example. Wiley.
#
# [36] Lattin, J. M. (2009). Interpreting Regression Coefficients. Journal of Consumer Research, 35(3), 580-581.
#
# [37] Justice, J. H., Montgomery, J. D., & Peck, G. C. (2012). Regression Analysis: Concepts and Applications. CRC Press.
#
# [38] Kreiser, L. J., & Vu, T. (2014). Understanding Regression Analysis: An Introductory Guide. The Journal of Applied Business Research, 30(2), 497-504.
#
# [39] Dietterich, T. G. (2011). Model Evaluation, Model Selection, and Algorithm Selection in Machine Learning. In Proceedings of the International Conference on Machine Learning (ICML), 28(3), 841-848.
#
# [40] James, G., Witten, D., Hastie, T., & Tibshirani, R. (2013). An Introduction to Statistical Learning: with Applications in R. Springer.
#
# [41] Chereches, A., & Burdescu, D. D. (2019). Machine Learning Models for Insurance: Predicting Insurance Claims. Procedia Computer Science, 160, 311-318.
#
# [42] Hotho, A., Lemke, S., & Stahl, C. (2018). Evaluation of Machine Learning Models. Springer.

# %% [markdown]
# <a name="id"></a>
# [**Back to HOME**](#100)

# %% [markdown]
# # Import Data and Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from wordcloud import WordCloud
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score, roc_auc_score, roc_curve
import seaborn as sns
from sklearn.preprocessing import LabelBinarizer

# Load dataset
col_name = ['id', 'brand', 'sentiment', 'tweet']
df = pd.read_csv('twitter_training.csv', names=col_name)

# %% [markdown]
# # Cleaning Data

# %%
# Remove 'id' column as it is not needed
df = df.drop(columns=["id"])

# Clean the data: Remove missing values and duplicates
df.dropna(inplace=True)  # Remove missing values
df.drop_duplicates(inplace=True)  # Remove duplicates

# Check the cleaned data
df
# Out:
#                      brand   sentiment  \
# 0              Borderlands    Positive
# 1              Borderlands    Positive
# 2              Borderlands    Positive
# 3              Borderlands    Positive
# 4              Borderlands    Positive
# ...                    ...         ...
# 60950  GrandTheftAuto(GTA)  Irrelevant
# 60951  GrandTheftAuto(GTA)  Irrelevant
# 60952  GrandTheftAuto(GTA)  Irrelevant
# 60953  GrandTheftAuto(GTA)  Irrelevant
# 60954  GrandTheftAuto(GTA)  Irrelevant
#
#                                                    tweet
# 0      im getting on borderlands and i will murder yo...
# 1      I am coming to the borders and I will kill you...
# 2      im getting on borderlands and i will kill you ...
# 3      im coming on borderlands and i will murder you...
# 4      im getting on borderlands 2 and i will murder ...
# ...                                                  ...
# 60950  Whoever vandalizing the speed cameras around t...
# ...

# %% [markdown]
# # Data Visualization

# %%
# Wordcloud for most frequent words in tweets
def plot_wordcloud(data):
    text = " ".join(tweet for tweet in data)
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.show()

plot_wordcloud(df['tweet'])

# %%
# Sentiment distribution
sentiment_counts = df['sentiment'].value_counts()
sentiment_counts.plot(kind='bar', figsize=(8, 5), color=['green', 'red', 'blue'])
plt.title("Sentiment Distribution")
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
# Brand distribution
brand_counts = df['brand'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(brand_counts, labels=brand_counts.index, autopct='%1.1f%%', startangle=140, colors=['cyan', 'magenta', 'yellow', 'orange', 'purple'])
plt.title("Brand Distribution")
plt.axis('equal')
plt.show()

# %%
# Visualize sentiment distribution for each brand
sentiment_by_brand = df.groupby(['brand', 'sentiment']).size().unstack().fillna(0)

# Plot stacked bar chart
sentiment_by_brand.plot(kind='bar', stacked=True, figsize=(12, 8), color=['red', 'yellow', 'green'])

# Title and labels
plt.title('Sentiment Distribution for Each Brand')
plt.xlabel('Brand')
plt.ylabel('Count')

# Adjust x-axis label rotation and spacing
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.subplots_adjust(bottom=0.2)

# Add legend
plt.legend(title='Sentiment', labels=['Negative', 'Neutral', 'Positive'])

# Final layout adjustments and display
plt.tight_layout()
plt.show()

# %% [markdown]
# # Preprocessing and Build Model

# %%
# Define the feature and target variable
X = df['tweet']
y = df['sentiment']

# Text vectorization (using TF-IDF)
tfidf = TfidfVectorizer(stop_words='english')

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Fit TF-IDF on training data
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# Train a model (Naive Bayes classifier)
model = MultinomialNB()
model.fit(X_train_tfidf, y_train)

# 6. Model evaluation
y_pred = model.predict(X_test_tfidf)

# %%
# Accuracy
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=np.unique(y), yticklabels=np.unique(y))
plt.title("Confusion Matrix")
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Accuracy: 0.7430743535103381

# %% [markdown]
# # Evaluation

# %%
# Precision, Recall, F1 Score
print(f"Precision: {precision_score(y_test, y_pred, average='weighted')}")
print(f"Recall: {recall_score(y_test, y_pred, average='weighted')}")
print(f"F1 Score: {f1_score(y_test, y_pred, average='weighted')}")

# ROC Curve for Multi-Class
lb = LabelBinarizer()
y_test_bin = lb.fit_transform(y_test)
y_pred_proba = model.predict_proba(X_test_tfidf)

# Plot ROC curve for each class
plt.figure(figsize=(10, 8))

n_classes = len(lb.classes_)
for i in range(n_classes):
    fpr, tpr, _ = roc_curve(y_test_bin[:, i], y_pred_proba[:, i])
    plt.plot(fpr, tpr, label=f'Class {lb.classes_[i]} (AUC = {roc_auc_score(y_test_bin[:, i], y_pred_proba[:, i]):.2f})')

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Multi-Class Classification')
plt.legend(loc='lower right')
plt.show()
# Out:
# Precision: 0.7781326925308314
# Recall: 0.7430743535103381
# F1 Score: 0.7363281301201225
